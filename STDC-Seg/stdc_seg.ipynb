# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!git clone https://github.com/MichaelFan01/STDC-Seg.git
# Out:
# /content/drive/MyDrive/AML_Semantic_Segmentation/STDC-Seg

# %%
# %cd /content/drive/MyDrive/AML_Semantic_Segmentation/STDC-Seg

# !pip install -U pip setuptools wheel
# !pip install -U torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# !pip install -r requirements_colab.txt

# !pip install -U ninja
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 114.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 188.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 69.6 MB/s  0:00:03
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [thop]
# ...

# %%
# %cd /content/drive/MyDrive/AML_Semantic_Segmentation/STDC-Seg/

# !export CUDA_VISIBLE_DEVICES=0
# !torchrun --standalone --nproc_per_node=1 train.py \
  --respath checkpoints/train_STDC1-Seg/ \
  --backbone STDCNet813 \
  --mode train \
  --n_workers_train 2 \
  --n_workers_val 1 \
  --max_iter 60000 \
  --use_boundary_8 True \
  --pretrain_path checkpoints/STDCNet813M_73.91.tar
# Out:
# /content/drive/MyDrive/AML_Semantic_Segmentation/STDC-Seg
# W0901 10:44:07.723000 16481 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W0901 10:44:07.723000 16481 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# n_workers_train: 2
# n_workers_val: 1
# use_boundary_2: False
# use_boundary_4: False
# use_boundary_8: True
# use_boundary_16: False
# mode: train
# Num campioni TRAIN: 1156
# steps_per_epoch = 72
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/content/drive/MyDrive/AML_Semantic_Segmentation/STDC-Seg/train.py", line 529, in <module>
# [rank0]:     train()
# [rank0]:   File "/content/drive/MyDrive/AML_Semantic_Segmentation/STDC-Seg/train.py", line 259, in train
# [rank0]:     steps_per_epoch = floor( len(train_dataset) / (batch_size_per_gpu * world_size) )
# [rank0]:                       ^^^^^
# ...
