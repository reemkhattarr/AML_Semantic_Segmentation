# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Dependencies
# %cd /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet
# !pip install -q numpy opencv-python pillow matplotlib
# !pip install -q thop gdown yacs
# !pip install tensorboardX
# Out:
# /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 60.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 99.7 MB/s eta 0:00:00
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (25.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (5.29.5)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.4

# %%
#Train
# %cd /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/tools
# !python train.py --cfg ../configs/loveda_pidnet_step_2b.yaml
# Out:
# /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/tools
# Seeding with 304
# => creating /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/output/pidnet_loveda_step_2b/loveda/loveda_pidnet_step_2b
# => creating /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/logs/pidnet_loveda_step_2b/loveda/pidnet/loveda_pidnet_step_2b_2025-08-09-17-00
# Namespace(cfg='../configs/loveda_pidnet_step_2b.yaml', seed=304, opts=[])
# AUTO_RESUME: False
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   DATASET: loveda
#   EXTRA_TRAIN_SET: None
#   NUM_CLASSES: 7
#   ROOT: /content/drive/MyDrive/AML_Semantic_Segmentation/data/LoveDA
#   TEST_SET: /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/data/list/loveda/Val/Rural/val.lst
#   TRAIN_SET: /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/data/list/loveda/Train/Rural/train.lst
# GPUS: (0,)
# LOG_DIR: /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/logs/pidnet_loveda_step_2b
# LOSS:
#   BALANCE_WEIGHTS: [0.4, 1.0]
#   CLASS_BALANCE: False
#   OHEMKEEP: 131072
#   OHEMTHRES: 0.9
#   SB_WEIGHTS: 0.5
#   USE_OHEM: True
# MODEL:
#   ALIGN_CORNERS: True
#   NAME: pidnet
#   NUM_OUTPUTS: 2
#   PRETRAINED: /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/pretrained_models/imagenet/PIDNet_S_ImageNet.pth.tar
# OUTPUT_DIR: /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/output/pidnet_loveda_step_2b
# PIN_MEMORY: True
# PRINT_FREQ: 20
# TEST:
#   BASE_SIZE: 1024
#   BATCH_SIZE_PER_GPU: 32
#   FLIP_TEST: False
#   IMAGE_SIZE: [1024, 1024]
#   MODEL_FILE: None
#   MULTI_SCALE: False
#   OUTPUT_INDEX: -1
# TRAIN:
#   BASE_SIZE: 1024
#   BATCH_SIZE_PER_GPU: 4
#   BEGIN_EPOCH: 0
#   END_EPOCH: 1
#   EXTRA_EPOCH: 0
#   EXTRA_LR: 0.001
#   FLIP: False
#   IGNORE_LABEL: -1
#   IMAGE_SIZE: [512, 512]
#   LR: 0.01
#   MOMENTUM: 0.9
#   MULTI_SCALE: False
#   NESTEROV: False
#   OPTIMIZER: sgd
#   RESUME: False
#   SCALE_FACTOR: None
#   SHUFFLE: True
#   WD: 0.0001
# WORKERS: 4
# Attention!!!
# Loaded 50 parameters!
# Over!!!
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch: [0/1] Iter:[0/341], Time: 12.69, lr: [0.01], Loss: 21.533039, Acc:0.113011, Semantic loss: 9.922580, BCE loss: 8.129586, SB loss: 3.480873
# Epoch: [0/1] Iter:[20/341], Time: 0.96, lr: [0.009470558434502847], Loss: 14.527058, Acc:0.280644, Semantic loss: 6.237598, BCE loss: 3.923396, SB loss: 4.366065
# Epoch: [0/1] Iter:[40/341], Time: 0.66, lr: [0.008937805611353848], Loss: 10.270703, Acc:0.348668, Semantic loss: 4.398478, BCE loss: 2.957074, SB loss: 2.915151
# Epoch: [0/1] Iter:[60/341], Time: 0.59, lr: [0.00840149835753541], Loss: 8.561060, Acc:0.358897, Semantic loss: 3.657941, BCE loss: 2.624514, SB loss: 2.278606
# Epoch: [0/1] Iter:[80/341], Time: 0.53, lr: [0.007861356938519599], Loss: 7.701231, Acc:0.371410, Semantic loss: 3.278049, BCE loss: 2.385637, SB loss: 2.037544
# Epoch: [0/1] Iter:[100/341], Time: 0.51, lr: [0.007317056309496819], Loss: 7.101187, Acc:0.386829, Semantic loss: 3.009264, BCE loss: 2.301697, SB loss: 1.790226
# Epoch: [0/1] Iter:[120/341], Time: 0.49, lr: [0.006768214362881021], Loss: 6.576763, Acc:0.407035, Semantic loss: 2.773815, BCE loss: 2.190079, SB loss: 1.612869
# Epoch: [0/1] Iter:[140/341], Time: 0.47, lr: [0.006214375770208739], Loss: 6.246877, Acc:0.410099, Semantic loss: 2.634000, BCE loss: 2.124556, SB loss: 1.488321
# Epoch: [0/1] Iter:[160/341], Time: 0.47, lr: [0.005654989153777177], Loss: 6.016908, Acc:0.417536, Semantic loss: 2.514530, BCE loss: 2.110582, SB loss: 1.391795
# Epoch: [0/1] Iter:[180/341], Time: 0.46, lr: [0.00508937377186087], Loss: 5.817487, Acc:0.424693, Semantic loss: 2.428169, BCE loss: 2.071128, SB loss: 1.318190
# Epoch: [0/1] Iter:[200/341], Time: 0.45, lr: [0.004516668952649948], Loss: 5.651281, Acc:0.431132, Semantic loss: 2.353090, BCE loss: 2.046254, SB loss: 1.251937
# Epoch: [0/1] Iter:[220/341], Time: 0.45, lr: [0.003935753516843512], Loss: 5.514956, Acc:0.436317, Semantic loss: 2.288752, BCE loss: 2.022106, SB loss: 1.204098
# Epoch: [0/1] Iter:[240/341], Time: 0.45, lr: [0.003345109165909231], Loss: 5.416485, Acc:0.439350, Semantic loss: 2.242974, BCE loss: 2.008292, SB loss: 1.165220
# Epoch: [0/1] Iter:[260/341], Time: 0.44, lr: [0.0027425690830102773], Loss: 5.314394, Acc:0.443669, Semantic loss: 2.197726, BCE loss: 1.986362, SB loss: 1.130306
# Epoch: [0/1] Iter:[280/341], Time: 0.44, lr: [0.002124799279469569], Loss: 5.213330, Acc:0.450094, Semantic loss: 2.150276, BCE loss: 1.967465, SB loss: 1.095588
# Epoch: [0/1] Iter:[300/341], Time: 0.44, lr: [0.0014860264171201148], Loss: 5.129628, Acc:0.454146, Semantic loss: 2.112193, BCE loss: 1.950934, SB loss: 1.066501
# Epoch: [0/1] Iter:[320/341], Time: 0.43, lr: [0.0008138013841158856], Loss: 5.062495, Acc:0.460082, Semantic loss: 2.079592, BCE loss: 1.940503, SB loss: 1.042401
# Epoch: [0/1] Iter:[340/341], Time: 0.43, lr: [5.254374929168644e-05], Loss: 4.994955, Acc:0.464662, Semantic loss: 2.048240, BCE loss: 1.927744, SB loss: 1.018971
# 0
# 10
# 20
# 30
# 0 [0.65713552 0.29335611 0.02249929 0.01918533 0.1548978  0.01418111
#  0.10364974] 0.1807007013326439
# 1 [7.14928417e-01 4.04923354e-01 2.61678557e-02 3.26327308e-04
#  1.11402243e-03 6.25395015e-03 9.34505292e-02] 0.17816635087697236
# => saving checkpoint to /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/output/pidnet_loveda_step_2b/loveda/loveda_pidnet_step_2bcheckpoint.pth.tar
# Loss: 3.806, MeanIU:  0.1782, Best_mIoU:  0.1782
# [7.14928417e-01 4.04923354e-01 2.61678557e-02 3.26327308e-04
#  1.11402243e-03 6.25395015e-03 9.34505292e-02]
# Attention!!!
# Loaded 0 parameters!
# Over!!!
#
# === Model Metrics (post-training) ===
# weights:    best.pt
# input:      [1, 3, 1024, 1024]
# params:     37.31M (37308143)
# latency:    avg 31.98 ms | p50 31.51 | p95 34.01
# throughput: 31.27 FPS
# FLOPs:      287.00 GFLOPs
# Metriche salvate in /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/output/pidnet_loveda_step_2b/loveda/loveda_pidnet_step_2b/model_metrics.json
# Hours: 0
# Done

# %%
#Generate .lst
# %cd /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/tools
# !python generate_loveda_lists.py
# Out:
# /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/tools
# ✅ Creato /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/data/list/loveda/Train/Rural/train.lst con 1366 elementi.
# ✅ Creato /content/drive/MyDrive/AML_Semantic_Segmentation/PIDNet/data/list/loveda/Val/Rural/val.lst con 992 elementi.
