# %%
from google.colab import drive
drive.mount('/content/drive')

data_root = "/content/drive/MyDrive/AML_Segmentation_Project/data/LoveDA"
checkpoint_path = "/content/drive/MyDrive/AML_Segmentation_Project/checkpoints/pidnet/pidnet_s_imagenet.pth"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/AML_Segmentation_Project/

# !git clone https://github.com/XuJiacong/PIDNet.git

# %cd PIDNet
# !pip install -q numpy opencv-python pillow matplotlib
# !pip install -q thop gdown yacs
# Out:
# /content/drive/MyDrive/AML_Segmentation_Project
# fatal: destination path 'PIDNet' already exists and is not an empty directory.
# /content/drive/MyDrive/AML_Segmentation_Project/PIDNet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/tools/

# !python train.py --cfg ../configs/loveda_pidnet_step_2b.yaml
# Out:
# /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/tools
# Seeding with 304
# => creating loveda/loveda_pidnet_step_2b
# => creating loveda/pidnet/loveda_pidnet_step_2b_2025-08-06-14-51
# Namespace(cfg='../configs/loveda_pidnet_step_2b.yaml', seed=304, opts=[])
# AUTO_RESUME: False
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   DATASET: loveda
#   EXTRA_TRAIN_SET:
#   NUM_CLASSES: 7
#   ROOT: /content/drive/MyDrive/AML_Segmentation_Project/dataset/LoveDA
#   TEST_SET: list/cityscapes/val.lst
#   TRAIN_SET: list/cityscapes/train.lst
# GPUS: (0,)
# LOG_DIR:
# LOSS:
#   BALANCE_WEIGHTS: [0.5, 0.5]
#   CLASS_BALANCE: False
#   OHEMKEEP: 100000
#   OHEMTHRES: 0.9
#   SB_WEIGHTS: 0.5
#   USE_OHEM: True
# MODEL:
#   ALIGN_CORNERS: True
#   NAME: pidnet
#   NUM_OUTPUTS: 2
#   PRETRAINED: /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/pretrained_models/imagenet/PIDNet_S_ImageNet.pth.tar
# OUTPUT_DIR:
# PIN_MEMORY: True
# PRINT_FREQ: 20
# ...

# %%
yaml_content = """
DATASET:
  DATASET: LoveDA
  NUM_CLASSES: 7
  ROOT: /content/drive/MyDrive/AML_Segmentation_Project/dataset/LoveDA

MODEL:
  NAME: pidnet
  PRETRAINED: /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/pretrained_models/imagenet/PIDNet_S_ImageNet.pth.tar

TRAIN:
  BEGIN_EPOCH: 0
  END_EPOCH: 20
  BATCH_SIZE_PER_GPU: 4
  IMAGE_SIZE: (512, 512)
  LR: 0.01
  OPTIMIZER: sgd
"""

with open("/content/drive/MyDrive/AML_Segmentation_Project/PIDNet/configs/loveda_pidnet.yaml", "w") as f:
    f.write(yaml_content.strip())

# %%
gitignore_content = """
# Ignora solo il dataset LoveDA
dataset/LoveDA/
""".strip()

with open("/content/drive/MyDrive/AML_Segmentation_Project/.gitignore", "w") as f:
    f.write(gitignore_content)

# %%
# ✅ Vai nella directory del progetto
# %cd /content/drive/MyDrive/AML_Segmentation_Project

# ✅ Inizializza Git se non già fatto
# !git init

# ✅ Collega il repository remoto (SOSTITUISCI con il tuo link!)
# !git remote add origin https://github.com/reemkhattarr/AML_Semantic_Segmentation.git

# ✅ Configura utente Git (solo la prima volta)
# !git config --global user.name "Giorgio-Galasso"
# !git config --global user.email "giorgio.galasso@outlook.it"

# ✅ Aggiungi tutti i file (escludendo quelli del .gitignore)
# !git add .

# ✅ Fai il commit
# !git commit -m "Push step_2b"

# ✅ Imposta il branch principale e fai push
# !git branch -M main
# !git push origin main
# Out:
# /content/drive/MyDrive/AML_Segmentation_Project
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/AML_Segmentation_Project/.git/
# error: 'PIDNet/' does not have a commit checked out
# fatal: adding files failed
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.gitignore
# 	PIDNet/
# 	step_2b/
#
# nothing added to commit but untracked files present (use "git add" to track)
# ...

# %%
# 1. Vai nella cartella del progetto
# %cd /content/drive/MyDrive/AML_Segmentation_Project

# 2. Rimuovi eventuale repo Git interna alla cartella PIDNet (causa errore)
# !rm -rf PIDNet/.git

# 4. Inizializza Git nella root del progetto
# !git init

# 5. Rinomina il branch in 'main' (evita warning)
# !git branch -m main

# 6. Collega il repository GitHub remoto (sostituisci con il tuo se diverso)
# !git remote add origin https://github.com/reemkhattarr/AML_Semantic_Segmentation.git

# 7. Configura utente Git (una tantum)
# !git config --global user.name "Giorgio-Galasso"
# !git config --global user.email "giorgio.galasso@outlook.it"

# 8. Aggiungi tutti i file tracciabili (rispettando il .gitignore)
# !git add .

# 9. Crea il commit
# !git commit -m "Aggiunti file .lst per LoveDA e script generazione liste"

# 10. Fai il push al ramo 'main'
# !git push -u origin main
# Out:
# /content/drive/MyDrive/AML_Segmentation_Project
# Reinitialized existing Git repository in /content/drive/MyDrive/AML_Segmentation_Project/.git/
# error: remote origin already exists.
# [main e31409c] Push step_2b
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git push https://Giorgio-Galasso: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@github.com/reemkhattarr/AML_Semantic_Segmentation.git main
# Out:
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/reemkhattarr/AML_Semantic_Segmentation.git/'

# %%
# !git add .
# !git commit -m "Push step_2b"
# Out:
# [main 70b3970] Push step_2b

# %%
# !git commit -m "Push step_2b"
# Out:
# [main 505d241] Push step_2b

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/tools
# !python generate_loveda_lists.py
# Out:
# /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/tools
# ✅ Creato /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/data/list/loveda/Train/Rural/train.lst con 1366 elementi.
# ✅ Creato /content/drive/MyDrive/AML_Segmentation_Project/PIDNet/data/list/loveda/Val/Rural/val.lst con 992 elementi.

# %%
# !git commit -m "Aggiunti file .lst per LoveDA e script generazione liste"
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
